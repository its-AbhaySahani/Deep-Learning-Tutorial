# %%
pip install pyspark
# Out:
# ...
#                                               0.0/317.3 MB ? eta -:--:--
#                                               0.0/317.3 MB ? eta -:--:--
#                                               0.0/317.3 MB ? eta -:--:--
#                                               0.0/317.3 MB ? eta -:--:--
#                                               0.0/317.3 MB ? eta -:--:--
#                                               0.0/317.3 MB ? eta -:--:--
#                                               0.0/317.3 MB ? eta -:--:--
#                                               0.0/317.3 MB ? eta -:--:--
#                                               0.0/317.3 MB ? eta -:--:--
#                                               0.0/317.3 MB ? eta -:--:--
#                                               0.0/317.3 MB ? eta -:--:--
#                                               0.0/317.3 MB ? eta -:--:--
#                                               0.0/317.3 MB ? eta -:--:--
# ...

# %%
import pyspark
